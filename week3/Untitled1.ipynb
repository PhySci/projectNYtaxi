# %%
import numpy as np

# %%
A = np.random.rand(5,10,3)

# %%
A
# Out:
# array([[[ 0.9831219 ,  0.59905709,  0.68586224],
#         [ 0.4699767 ,  0.57513364,  0.85483791],
#         [ 0.81506181,  0.10120002,  0.46854352],
#         [ 0.49807401,  0.63347058,  0.29299556],
#         [ 0.06375744,  0.09283747,  0.72976473],
#         [ 0.81054011,  0.98024503,  0.15167299],
#         [ 0.48584583,  0.55087529,  0.69262213],
#         [ 0.95590085,  0.0329932 ,  0.4689352 ],
#         [ 0.9022973 ,  0.32225372,  0.75055021],
#         [ 0.00822895,  0.82120263,  0.84584479]],
#
#        [[ 0.06478259,  0.10384711,  0.11669186],
#         [ 0.51859314,  0.91123532,  0.43072089],
#         [ 0.95911737,  0.91486269,  0.73621758],
#         [ 0.52563572,  0.1854889 ,  0.55204283],
#         [ 0.57545222,  0.44150179,  0.48140989],
#         [ 0.13227009,  0.8968653 ,  0.18067235],
#         [ 0.82116593,  0.48443886,  0.31230842],
#         [ 0.91173689,  0.45956475,  0.99631293],
#         [ 0.0039856 ,  0.83753595,  0.22828495],
# ...

# %%
A[0,0,0]
# Out:
# 0.98312190188854276

# %%
A[:,0,0]
# Out:
# array([ 0.9831219 ,  0.06478259,  0.62963642,  0.71188258,  0.37773407])

# %%
A[]
