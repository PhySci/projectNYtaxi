# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
from sklearn import linear_model
from datetime import datetime
from itertools import product
import statsmodels.api as sm
import warnings

# %matplotlib inline

# %%
# подгружаем данные

# id нужных регионов
regsDf = pd.read_csv('../crowdRegs.csv',names=['id','regId']);  

# временные ряды для этих регионов
df = pd.read_pickle('../loadData/crowdRegs3.pcl')
df.columns = regsDf.regId.values.astype('str')

# словарь с группировкой рядов
tsGroups = np.load('tsGroups.npy').item()

# %%
startDate = '2016-01-01 0:0:0'
endDate = '2016-04-30 23:59:59'

# %% [markdown]
# Теперь надо подобрать параметры моделей. Для этого можно использовать какой-то один ряд, либо попробовоть усреднять ряды внутри групп и уже для усреднённых рядов подбирать параметры.
#
# Для начала построим и визуально оценим усреднение. Возьмём первую группу.

# %%
gr = 'gr4'
for grName, grVal in tsGroups.items():
    grSeries = df.loc[:,grVal].apply(lambda x: (x - x.mean()), raw = True)
    grSeries = grSeries.apply(lambda x: x /(x.std()), raw = True)
    
    plt.plot()
    grSeries.assign(ms = grSeries.mean(1)).plot(subplots = True,figsize = [15,10])
    plt.title(grName)
    plt.xlim(['2016-01-02','2016-01-31'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c1875acfc007> in <module>()
#       5
#       6     plt.plot()
# ----> 7     grSeries.assign(ms = grSeries.mean(1)).plot(subplots = True,figsize = [15,10])
#       8     plt.title(grName)
#       9     plt.xlim(['2016-01-02','2016-01-31'])
#
# /home/frodos/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /home/frodos/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /home/frodos/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /home/frodos/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#    1040         self._args_adjust()
#    1041         self._compute_plot_data()
# -> 1042         self._setup_subplots()
#    1043         self._make_plot()
#    1044         self._add_table()
#
# /home/frodos/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _setup_subplots(self)
#    1088                                   figsize=self.figsize, ax=self.ax,
#    1089                                   layout=self.layout,
# -> 1090                                   layout_type=self._layout_type)
#    1091         else:
#    1092             if self.ax is None:
#
# /home/frodos/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#    3430             kwds['sharex'] = None
#    3431             kwds['sharey'] = None
# -> 3432         ax = fig.add_subplot(nrows, ncols, i + 1, **kwds)
#    3433         axarr[i] = ax
#    3434
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1018                     self._axstack.remove(ax)
#    1019
# -> 1020             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1021
#    1022         self._axstack.add(key, a)
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     549
#     550         self._connected = {}  # a dict from events to (id, func)
# --> 551         self.cla()
#     552         # funcs used to format x and y - fall back on major formatters
#     553         self.fmt_xdata = None
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in cla(self)
#     976         self.yaxis.cla()
#     977         for name, spine in six.iteritems(self.spines):
# --> 978             spine.cla()
#     979
#     980         self.ignore_existing_data_limits = True
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/spines.pyc in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     419                           markersize=self._size,
#     420                           markeredgewidth=self._width, zorder=self._zorder)
# --> 421         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     422         self._set_artist_props(l)
#     423         return l
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in get_xaxis_transform(self, which)
#     704         elif which == 'tick1':
#     705             # for cartesian projection, this is bottom spine
# --> 706             return self.spines['bottom'].get_spine_transform()
#     707         elif which == 'tick2':
#     708             # for cartesian projection, this is top spine
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/spines.pyc in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/spines.pyc in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/spines.pyc in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     418                           linestyle='None', marker=self._tickmarkers[0],
#     419                           markersize=self._size,
# --> 420                           markeredgewidth=self._width, zorder=self._zorder)
#     421         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     422         self._set_artist_props(l)
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     423         self.set_markeredgewidth(markeredgewidth)
#     424
# --> 425         self.set_fillstyle(fillstyle)
#     426
#     427         self.verticalOffset = None
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in set_fillstyle(self, fs)
#     553         ACCEPTS: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#     554         """
# --> 555         self._marker.set_fillstyle(fs)
#     556         self.stale = True
#     557
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in set_fillstyle(self, fillstyle)
#     235                              % ' '.join(self.fillstyles))
#     236         self._fillstyle = fillstyle
# --> 237         self._recache()
#     238
#     239     def get_joinstyle(self):
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in _recache(self)
#     198
#     199     def _recache(self):
# --> 200         self._path = Path(np.empty((0, 2)))
#     201         self._transform = IdentityTransform()
#     202         self._alt_path = None
#
# /home/frodos/anaconda/lib/python2.7/site-packages/matplotlib/path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     158
#     159         self._vertices = vertices
# --> 160         self._codes = codes
#     161         self._interpolation_steps = _interpolation_steps
#     162         self._update_values()
#
# KeyboardInterrupt:

# %%
# выберу настроечные ряды руками
fitSeries = {'gr18':'1274','gr19':'1684','gr10':'1333','gr11':'1075','gr12':'2118','gr13':'1387','gr14':'1384','gr15':'1174'}
fitSeries.update({'gr16':'1483','gr17':'1282','gr21':'1184','gr20':'1131','gr23':'1332','gr22':'1580','gr6':'1326','gr7':'1388'})
fitSeries.update({'gr4':'1129','gr2':'1234','gr3':'1231','gr0':'1286','gr1':'1125','gr8':'1181','gr9':'1532'})

# %%
# Рядов много, модели обучаются долго, а ресурсов - мало. Поэтому будет подбирать параметры только для малых p и q.
ps = range(1, 5)
d=1
qs = range(1, 5)

Ps = range(1, 3)
D=1
Qs = range(1, 3)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)

len(parameters_list)
# Out:
# 64

# %%
def addFeatures(res, Kw = 6, Ka = 3,verbose = False):    
    # add linear feature
    res = res.assign(hours = (res.index - datetime.datetime(2014,1,1,0,0,0))/np.timedelta64(1, 'h'))
    
    # добавляем гармонические фичи
    for ind in range(1,Kw+1):
        res['weekCos'+str(ind)]= np.cos(np.pi*res.hours*ind/168);
        res['weekSin'+str(ind)]= np.sin(np.pi*res.hours*ind/168);
    for ind in range(1,Ka+1):
        res['yearCos'+str(ind)]= np.cos(2*np.pi*res.hours*ind/8766);
        res['yearSin'+str(ind)]= np.sin(2*np.pi*res.hours*ind/8766);
        
    # добавляем dummy variables для дней недели
    lbDays = preprocessing.LabelBinarizer()
    lbDays.fit(list(np.arange(6)))
    DoW = pd.DataFrame(lbDays.transform(res.index.dayofweek),columns = ['DayOfWeek_'+str(x) for x in np.arange(6)],
                       index = res.index)      
    res = res.merge(DoW,left_index=True,right_index=True)
 
    # добавляем dummy variables для месяца
    lbMonths = preprocessing.LabelBinarizer()
    lbMonths.fit(list(np.arange(12)))
    Months = pd.DataFrame(lbMonths.transform(res.index.month),columns = ['Month_'+str(x) for x in np.arange(12)],index = res.index)      
    res = res.merge(Months,left_index=True,right_index=True);
    return res

def regression(res, alpha = 0.1, plot = False,verbose = False):
    X = res.drop('trip_count',axis = 1)        
    y = res.loc[:,'trip_count'];
    lassoReg = linear_model.Lasso(alpha = alpha, max_iter = 1e5,fit_intercept = True,random_state = 0);
    lassoReg.fit(X,y)
    y_pr = pd.Series(data = lassoReg.predict(X), index = res.index)
    R = lassoReg.score(X,y);
    print 'R factor is ', R
    
    if plot:
        plt.figure(figsize = [15,10])
        plt.subplot(211)
        plt.plot(y)
        plt.plot(y_pr)
        plt.legend(['Original data','Predicted'])

        plt.subplot(212)
        plt.plot(y-y_pr)
        plt.legend(['Residuals'])
        
    return [y_pr, y-y_pr, lassoReg]

def findHyperParams(ts,pList):
    results = []
    best_aic = float("inf")
    
    # add features
    ts = addFeatures(ts, Kw = 6, Ka = 3)
    # regression
    [s, r, lasso] = regression(ts,alpha = 0.01)
    
    # loop over parameters' list
    for param in pList:
        #try except нужен, потому что на некоторых наборах параметров модель не обучается
        print('Parameters:', param)
        try:
            mSARIMA=sm.tsa.statespace.SARIMAX(df.loc[startDate:endDate,tsName].to_frame(), order=[param[0], 1, param[1]],
                                          seasonal_order=(param[2], 1, param[3], 24),exog = r,
                                             enforce_invertibility = True).fit(disp=1);
        #выводим параметры, на которых модель не обучается и переходим к следующему набору
        except Exception as inst:
            print type(inst)     # the exception instance
            print inst           # __str__ allows args to be printed directly
            continue
        aic = mSARIMA.aic
        print('AIC',aic) 
        #сохраняем лучшую модель, aic, параметры
        if aic < best_aic:
            best_model = mSARIMA
            best_aic = aic
            best_param = param
        results.append([param, mSARIMA.aic])
    print results
    return [best_aic,best_param]
    

    
#%%time
warnings.filterwarnings('ignore')
paramsDict = {}

for grName, tsName in fitSeries.iteritems():
    
    print 'New groups'
    print grName, tsName
    
    [aic, best_param] = findHyperParams(df.loc[startDate:endDate,tsName].to_frame(name = 'count'),parameters_list)
    
    paramsDict.update({grName: [aic, best_param]})
    print paramsDict
    
warnings.filterwarnings('default')
# Out:
# New groups
# gr21 1184
# R factor is  0.0238219675232
# ('Parameters:', (1, 1, 1, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 1, 2, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 1, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 2, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 1, 1))
# ('AIC', 6998.3458783954738)
# ('Parameters:', (1, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 2, 1))
# ('AIC', 5618.6377390093694)
# ('Parameters:', (1, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 4, 1, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 2, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 1, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 1, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 1, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 1, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 1, 1, 1))
# ('AIC', 7127.1076865552477)
# ('Parameters:', (3, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 1, 2, 1))
# ('AIC', 5550.6011006586668)
# ('Parameters:', (3, 1, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 1, 1, 1))
# ('AIC', 7152.4446123095586)
# ('Parameters:', (4, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 1, 2, 1))
# ('AIC', 5572.3265128971461)
# ('Parameters:', (4, 1, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# [[(1, 3, 1, 1), 6998.3458783954738], [(1, 3, 2, 1), 5618.6377390093694], [(3, 1, 1, 1), 7127.1076865552477], [(3, 1, 2, 1), 5550.6011006586668], [(4, 1, 1, 1), 7152.4446123095586], [(4, 1, 2, 1), 5572.3265128971461]]
# {'gr21': [5572.3265128971461, (3, 1, 2, 1)]}
# New groups
# gr20 1131
# R factor is  0.138892350186
# ('Parameters:', (1, 1, 1, 1))
# ('AIC', 21884.440006084857)
# ('Parameters:', (1, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 1, 2, 1))
# ('AIC', 21388.578029163502)
# ('Parameters:', (1, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 3, 1, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 2, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 1, 1))
# ('AIC', 21840.140157349066)
# ('Parameters:', (1, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 2, 1))
# ('AIC', 21377.053774451186)
# ('Parameters:', (1, 4, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 1, 1, 1))
# ('AIC', 21885.10513865071)
# ('Parameters:', (2, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 1, 2, 1))
# ('AIC', 21388.884514554797)
# ('Parameters:', (2, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 1, 1))
# <class 'numpy.linalg.linalg.LinAlgError'>
# Singular matrix
# ('Parameters:', (2, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 4, 2, 1))
# <type 'exceptions.ValueError'>
# array must not contain infs or NaNs
# ('Parameters:', (2, 4, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 1, 1, 1))
# ('AIC', 21886.908024559169)
# ('Parameters:', (3, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 1, 2, 1))
# ('AIC', 21393.420330928726)
# ('Parameters:', (3, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 1, 1))
# <class 'numpy.linalg.linalg.LinAlgError'>
# Singular matrix
# ('Parameters:', (3, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 4, 2, 1))
# <type 'exceptions.ValueError'>
# array must not contain infs or NaNs
# ('Parameters:', (3, 4, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 1, 1, 1))
# ('AIC', 21888.80866018455)
# ('Parameters:', (4, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 1, 2, 1))
# ('AIC', 21395.278540966883)
# ('Parameters:', (4, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 1, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 4, 2, 1))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 4, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting MA parameters found with `enforce_invertibility` set to True.
# [[(1, 1, 1, 1), 21884.440006084857], [(1, 1, 2, 1), 21388.578029163502], [(1, 4, 1, 1), 21840.140157349066], [(1, 4, 2, 1), 21377.053774451186], [(2, 1, 1, 1), 21885.10513865071], [(2, 1, 2, 1), 21388.884514554797], [(3, 1, 1, 1), 21886.908024559169], [(3, 1, 2, 1), 21393.420330928726], [(4, 1, 1, 1), 21888.80866018455], [(4, 1, 2, 1), 21395.278540966883]]
# {'gr21': [5572.3265128971461, (3, 1, 2, 1)], 'gr20': [21395.278540966883, (1, 4, 2, 1)]}
# New groups
# gr23 1332
# R factor is  0.038602410266
# ('Parameters:', (1, 1, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 1, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 1, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 1, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 2, 1, 1))
# ('AIC', 23372.949869245887)
# ('Parameters:', (1, 2, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 2, 1))
# ('AIC', 22804.2939455009)
# ('Parameters:', (1, 2, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 1, 1))
# ('AIC', 23375.079795070051)
# ('Parameters:', (1, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 2, 1))
# ('AIC', 22807.039447072588)
# ('Parameters:', (1, 3, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (1, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 1, 1, 1))
# ('AIC', 23372.769746215254)
# ('Parameters:', (2, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 1, 2, 1))
# ('AIC', 22803.721154213075)
# ('Parameters:', (2, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 3, 1, 1))
# ('AIC', 23464.918921584627)
# ('Parameters:', (2, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 3, 2, 1))
# ('AIC', 22807.524006698994)
# ('Parameters:', (2, 3, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (2, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 1, 1, 1))
# ('AIC', 23374.608285551498)
# ('Parameters:', (3, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 1, 2, 1))
# ('AIC', 22820.046333412494)
# ('Parameters:', (3, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (3, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 1, 1, 1))
# ('AIC', 23376.475375506452)
# ('Parameters:', (4, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 1, 2, 1))
# ('AIC', 22810.206506844228)
# ('Parameters:', (4, 1, 2, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 2, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 2, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 3, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 1, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 1, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 2, 1))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# ('Parameters:', (4, 4, 2, 2))
# <type 'exceptions.ValueError'>
# Non-stationary starting autoregressive parameters found with `enforce_stationarity` set to True.
# [[(1, 2, 1, 1), 23372.949869245887], [(1, 2, 2, 1), 22804.2939455009], [(1, 3, 1, 1), 23375.079795070051], [(1, 3, 2, 1), 22807.039447072588], [(2, 1, 1, 1), 23372.769746215254], [(2, 1, 2, 1), 22803.721154213075], [(2, 3, 1, 1), 23464.918921584627], [(2, 3, 2, 1), 22807.524006698994], [(3, 1, 1, 1), 23374.608285551498], [(3, 1, 2, 1), 22820.046333412494], [(4, 1, 1, 1), 23376.475375506452], [(4, 1, 2, 1), 22810.206506844228]]
# {'gr21': [5572.3265128971461, (3, 1, 2, 1)], 'gr20': [21395.278540966883, (1, 4, 2, 1)], 'gr23': [22810.206506844228, (2, 1, 2, 1)]}
# New groups
# gr22 1580
# R factor is  0.0320711751951
# ('Parameters:', (1, 1, 1, 1))
# ('AIC', -3253.5725978598057)
# ('Parameters:', (1, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 1, 2, 1))
# ('AIC', -4801.9052743290649)
# ('Parameters:', (1, 1, 2, 2))
# ('AIC', -5984.9757474875651)
# ('Parameters:', (1, 2, 1, 1))
# ('AIC', -3247.3252207401783)
# ('Parameters:', (1, 2, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 2, 2, 1))
# ('AIC', -4805.3168452867958)
# ('Parameters:', (1, 2, 2, 2))
# ('AIC', -6053.9505252967065)
# ('Parameters:', (1, 3, 1, 1))
# ('AIC', -3248.9518497992462)
# ('Parameters:', (1, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 3, 2, 1))
# ('AIC', -4769.6114833762476)
# ('Parameters:', (1, 3, 2, 2))
# ('AIC', -6039.6777627591955)
# ('Parameters:', (1, 4, 1, 1))
# ('AIC', -3238.9364401916391)
# ('Parameters:', (1, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (1, 4, 2, 1))
# ('AIC', -4840.1550237089996)
# ('Parameters:', (1, 4, 2, 2))
# ('AIC', -6053.561850971173)
# ('Parameters:', (2, 1, 1, 1))
# ('AIC', -3245.074812781846)
# ('Parameters:', (2, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 1, 2, 1))
# ('AIC', -4841.0892378291555)
# ('Parameters:', (2, 1, 2, 2))
# ('AIC', -6107.6632964708906)
# ('Parameters:', (2, 2, 1, 1))
# ('AIC', -3264.3728993154609)
# ('Parameters:', (2, 2, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 2, 2, 1))
# ('AIC', -4814.4790226319419)
# ('Parameters:', (2, 2, 2, 2))
# ('AIC', -6030.4397798481623)
# ('Parameters:', (2, 3, 1, 1))
# ('AIC', -3241.8284688679892)
# ('Parameters:', (2, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 3, 2, 1))
# ('AIC', -4799.7126829396639)
# ('Parameters:', (2, 3, 2, 2))
# ('AIC', -6023.6459651437217)
# ('Parameters:', (2, 4, 1, 1))
# ('AIC', -3245.2160718659875)
# ('Parameters:', (2, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (2, 4, 2, 1))
# ('AIC', -4839.8186167074491)
# ('Parameters:', (2, 4, 2, 2))
# ('AIC', -6079.7190492324426)
# ('Parameters:', (3, 1, 1, 1))
# ('AIC', -3236.617379445086)
# ('Parameters:', (3, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 1, 2, 1))
# ('AIC', -4788.1147196355014)
# ('Parameters:', (3, 1, 2, 2))
# ('AIC', -6050.5211565130703)
# ('Parameters:', (3, 2, 1, 1))
# ('AIC', -3260.4406159148139)
# ('Parameters:', (3, 2, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 2, 2, 1))
# ('AIC', -4778.6760635640558)
# ('Parameters:', (3, 2, 2, 2))
# ('AIC', -5968.4660499572328)
# ('Parameters:', (3, 3, 1, 1))
# ('AIC', -3212.4576154072633)
# ('Parameters:', (3, 3, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 3, 2, 1))
# ('AIC', -4791.9654865252123)
# ('Parameters:', (3, 3, 2, 2))
# ('AIC', -5969.3564677522554)
# ('Parameters:', (3, 4, 1, 1))
# <class 'numpy.linalg.linalg.LinAlgError'>
# Singular matrix
# ('Parameters:', (3, 4, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (3, 4, 2, 1))
# <type 'exceptions.ValueError'>
# array must not contain infs or NaNs
# ('Parameters:', (3, 4, 2, 2))
# <class 'numpy.linalg.linalg.LinAlgError'>
# Singular matrix
# ('Parameters:', (4, 1, 1, 1))
# ('AIC', -3239.83354576889)
# ('Parameters:', (4, 1, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 1, 2, 1))
# ('AIC', -4801.7940290830275)
# ('Parameters:', (4, 1, 2, 2))
# ('AIC', -6063.2467259533742)
# ('Parameters:', (4, 2, 1, 1))
# ('AIC', -3237.0659501804776)
# ('Parameters:', (4, 2, 1, 2))
# <type 'exceptions.ValueError'>
# non-invertible starting seasonal moving average parameters found with `enforce_invertibility` set to True.
# ('Parameters:', (4, 2, 2, 1))
# ('AIC', -4750.3070184208991)
# ('Parameters:', (4, 2, 2, 2))

# %%
df.loc[:,tsGroups['gr4']]
# Out:
#                      1127  1128  1129  1130
# 2014-01-01 00:00:00   645   589   799   948
# 2014-01-01 01:00:00   604   490   635   667
# 2014-01-01 02:00:00   571   465   499   455
# 2014-01-01 03:00:00   533   442   370   307
# 2014-01-01 04:00:00   383   296   319   261
# 2014-01-01 05:00:00   172   204   207   300
# 2014-01-01 06:00:00    97   148   147   207
# 2014-01-01 07:00:00    69   116    76   158
# 2014-01-01 08:00:00    76    77    84    74
# 2014-01-01 09:00:00    99    89   127   111
# 2014-01-01 10:00:00   145   130   163   134
# 2014-01-01 11:00:00   269   217   257   228
# 2014-01-01 12:00:00   306   271   348   334
# 2014-01-01 13:00:00   342   286   409   368
# 2014-01-01 14:00:00   371   324   448   389
# 2014-01-01 15:00:00   308   313   384   406
# 2014-01-01 16:00:00   270   237   330   353
# 2014-01-01 17:00:00   310   252   380   389
# 2014-01-01 18:00:00   337   317   363   361
# 2014-01-01 19:00:00   325   312   377   343
# 2014-01-01 20:00:00   236   285   377   310
# 2014-01-01 21:00:00   247   302   368   341
# 2014-01-01 22:00:00   178   294   393   409
# 2014-01-01 23:00:00   148   258   360   326
# 2014-01-02 00:00:00   132   197   233   324
# 2014-01-02 01:00:00    80   109   146   156
# 2014-01-02 02:00:00    33    94   110   121
# 2014-01-02 03:00:00    23    60    76    87
# 2014-01-02 04:00:00    27    47    53    49
# 2014-01-02 05:00:00    31    42    78    56
# ...                   ...   ...   ...   ...
# 2016-06-29 18:00:00   305   342   337   480
# 2016-06-29 19:00:00   402   437   370   504
# 2016-06-29 20:00:00   417   424   413   553
# 2016-06-29 21:00:00   461   525   503   671
# 2016-06-29 22:00:00   519   528   557   617
# 2016-06-29 23:00:00   414   583   592   680
# 2016-06-30 00:00:00   255   347   403   556
# 2016-06-30 01:00:00   196   232   249   379
# 2016-06-30 02:00:00   120   115   176   294
# 2016-06-30 03:00:00    78    58   104   222
# 2016-06-30 04:00:00    57    37    75   157
# 2016-06-30 05:00:00    63    52   104    66
# 2016-06-30 06:00:00   118   114   237   122
# 2016-06-30 07:00:00   224   196   333   176
# 2016-06-30 08:00:00   254   277   438   300
# 2016-06-30 09:00:00   296   278   420   342
# 2016-06-30 10:00:00   256   274   303   256
# 2016-06-30 11:00:00   239   295   234   242
# 2016-06-30 12:00:00   320   293   255   307
# 2016-06-30 13:00:00   293   285   233   298
# 2016-06-30 14:00:00   262   283   233   348
# 2016-06-30 15:00:00   223   236   230   314
# 2016-06-30 16:00:00   160   181   178   267
# 2016-06-30 17:00:00   226   218   280   404
# 2016-06-30 18:00:00   266   272   343   507
# 2016-06-30 19:00:00   308   401   336   496
# 2016-06-30 20:00:00   368   390   385   560
# 2016-06-30 21:00:00   422   460   541   672
# 2016-06-30 22:00:00   476   405   508   578
# 2016-06-30 23:00:00   428   483   531   631
#
# [21888 rows x 4 columns]

# %%
1127, 1128, 1129, 1130  , 1131, 1177, 1180, 1327, 1580,
# Out:
# (1127, 1128, 1129, 1130, 1131, 1177, 1180, 1327, 1580)

# %%
# Out:
# ['1127', '1128', '1129', '1130']

# %%
df.loc['2015-1':'2015-2',tsGroups.get('gr4')].plot(subplots = True, sharex = True,figsize = [15,20])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f56e471b610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f56e467f310>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f56de1f7490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f56e1de1c90>], dtype=object)
